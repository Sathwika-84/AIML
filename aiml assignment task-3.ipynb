# %%
import pandas as pd
tsv_file_path = '/content/task3.tsv'
tsv_data = pd.read_csv(tsv_file_path, sep='\t')
print(tsv_data)
# Out:
#        NAME       AGE  CITY
# 0       SRI        19  PDPL
# 1       SID        18   WGL
# 2   DHARANI        18   WGL
# 3  SATHWIKA        18  PDPL
# 4     NIVED        19   WGL
# 5      RAJA        19   HZB

# %%
xlsx_file_path = '/content/task3.xlsx'
xlsx_data = pd.read_excel(xlsx_file_path)
print(xlsx_data)
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0         NaN         NaN        NaN        NaN        NaN
# 1         NaN         NaN        NaN        NaN        NaN
# 2         NaN         NaN        NaN        NaN        NaN
# 3         NaN         NaN       NAME        AGE       CITY
# 4         NaN         NaN        SRI         19       PDPL
# 5         NaN         NaN        SID         18        WGL
# 6         NaN         NaN    DHARANI         18        WGL
# 7         NaN         NaN   SATHWIKA         18       PDPL
# 8         NaN         NaN      NIVED         19        WGL
# 9         NaN         NaN       RAJA         19        HZB

# %%
csv_file_path = '/content/Iris.csv'
csv_data = pd.read_csv(csv_file_path)
print(csv_data)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
url = 'https://github.com/jayeshbhandarkar/Iris-Dataset-Prediction-using-Unsupervised-ML/blob/main/Iris.csv'
data_from_url = pd.read_csv(url)
print(data_from_url)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-22b7f23623d5> in <cell line: 2>()
#       1 url = 'https://github.com/jayeshbhandarkar/Iris-Dataset-Prediction-using-Unsupervised-ML/blob/main/Iris.csv'
# ----> 2 data_from_url = pd.read_csv(url)
#       3 print(data_from_url)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
